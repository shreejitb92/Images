# %%
from IPython.display import Image

# %%
Image(filename='Logistic Regression ROC.png')

# %%
Image(filename='SVM and Random Forest ROC.png')

# %%
Image(filename='Boosting permormance.png')

# %%
Image(filename='Influence of various factors on malware.png')
